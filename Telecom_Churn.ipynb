# %% [markdown]
# # PREDICTING CHURN RATE IN TELECOM INDUSTRY

# %% [markdown]
# # IMPORTING THE REQUIRED LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split, KFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import confusion_matrix, classification_report

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # READING THE DATA

# %%
tc=pd.read_csv('Telecom.csv',na_values=[' ','/','?','$'])

# %%
pd.options.display.max_columns=None
#  option to view all the columns without missing any, in the outputs

# %%
tc.sample(5)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 5112  1383-EZRWL  Female              0      No         No       7
# 1883  8840-DQLGN  Female              1     Yes         No      35
# 1253  2026-TGDHM  Female              0      No         No       7
# 3167  5148-ORICT  Female              0     Yes         No      64
# 6227  2842-JTCCU    Male              0      No         No       2
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 5112          Yes            No              No  No internet service
# 1883          Yes           Yes     Fiber optic                  Yes
# 1253          Yes            No     Fiber optic                   No
# 3167          Yes            No             DSL                  Yes
# 6227          Yes            No             DSL                   No
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 5112  No internet service  No internet service  No internet service
# 1883                  Yes                   No                  Yes
# 1253                   No                   No                   No
# 3167                  Yes                  Yes                  Yes
# 6227                   No                   No                   No
#
#               StreamingTV      StreamingMovies        Contract  \
# 5112  No internet service  No internet service  Month-to-month
# 1883                  Yes                   No  Month-to-month
# 1253                   No                  Yes  Month-to-month
# 3167                   No                  Yes        Two year
# 6227                   No                   No  Month-to-month
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 5112               No               Mailed check           20.05
# 1883              Yes  Bank transfer (automatic)          100.50
# 1253              Yes           Electronic check           79.30
# 3167              Yes               Mailed check           74.35
# 6227               No  Bank transfer (automatic)           46.05
#
#       TotalCharges Churn
# 5112        164.85   Yes
# 1883       3653.35   Yes
# 1253        523.15   Yes
# 3167       4759.55    No
# 6227         80.35   Yes

# %%
tc[tc['InternetService']=='No']
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 11    7469-LKBCI    Male              0      No         No      16
# 16    8191-XWSZG  Female              0      No         No      52
# 21    1680-VDCWW    Male              0     Yes         No      12
# 22    1066-JKSGK    Male              0      No         No       1
# 33    7310-EGVHZ    Male              0      No         No       1
# 42    9867-JCZSP  Female              0     Yes        Yes      17
# 58    3957-SQXML  Female              0     Yes        Yes      34
# 68    3170-NMYVV  Female              0     Yes        Yes      50
# 71    0731-EBJQB  Female              0     Yes        Yes      52
# 73    8028-PNXHQ    Male              0     Yes        Yes      62
# 79    3887-PBQAO  Female              0     Yes        Yes      45
# 84    0318-ZOPWS  Female              0     Yes         No      49
# 87    1862-QRWPE  Female              0     Yes        Yes      48
# 88    2796-NNUFI  Female              0     Yes        Yes      46
# 97    0278-YXOOG    Male              0      No         No       5
# 98    3212-KXOCR    Male              0      No         No      52
# 100   6380-ARCEH    Male              0      No         No       1
# 101   3679-XASPY  Female              0     Yes        Yes       1
# 109   2848-YXSMW    Male              0     Yes        Yes      72
# 118   8402-OOOHJ  Female              0      No         No      41
# 121   2928-HLDBA  Female              0      No         No       6
# 124   7219-TLZHO  Female              0     Yes        Yes       4
# 127   6734-PSBAW    Male              0     Yes         No      72
# 128   3930-ZGWVE    Male              0      No         No       1
# 135   7799-LGRDP  Female              0      No         No      43
# 137   3774-VBNXY  Female              0     Yes        Yes      64
# 138   6217-KDYWC    Male              0      No        Yes      57
# 144   1131-QQZEB    Male              1     Yes         No      71
# 146   6837-BJYDQ    Male              0      No         No       3
# 154   3077-RSNTJ  Female              0     Yes        Yes       6
# ...          ...     ...            ...     ...        ...     ...
# 6830  7815-PDTHL    Male              0      No         No      35
# 6832  9173-IVZVP  Female              0     Yes        Yes      53
# 6840  1724-IQWNM    Male              0      No        Yes       1
# 6842  5546-QUERU    Male              0      No         No      13
# 6854  9700-ZCLOT    Male              0      No         No       2
# 6856  4534-WGCIR  Female              0     Yes        Yes      58
# 6867  5146-YYFRZ    Male              0      No         No      67
# 6875  6848-HJTXY  Female              0     Yes         No      64
# 6880  6976-BWGLQ  Female              0     Yes        Yes      72
# 6887  2511-ALLCS  Female              0     Yes        Yes      35
# 6906  9945-PSVIP  Female              0     Yes        Yes      25
# 6911  0508-SQWPL  Female              0     Yes        Yes      57
# 6916  7242-EDTYC    Male              0      No        Yes      44
# 6920  2595-KIWPV    Male              0      No        Yes      27
# 6925  6508-NJYRO    Male              0     Yes         No      15
# 6929  0357-NVCRI  Female              0      No        Yes      25
# 6942  3454-JFUBC    Male              1      No         No      68
# 6944  9039-ZVJDC    Male              0      No         No       3
# 6951  9588-YRFHY    Male              0      No         No      49
# 6954  9364-YKUVW    Male              0      No         No      15
# 6958  3078-ZKNTS  Female              0     Yes        Yes      13
# 6969  4745-LSPLO    Male              0      No         No       1
# 6994  0804-YGEQV  Female              0     Yes        Yes      43
# 7000  0052-YNYOT  Female              0      No         No      67
# 7005  9347-AERRL    Male              0     Yes         No      23
# 7017  4807-IZYOZ  Female              0      No         No      51
# 7019  9710-NJERN  Female              0      No         No      39
# 7020  9837-FWLCH    Male              0     Yes        Yes      12
# 7030  0871-OPBXW  Female              0      No         No       2
# 7037  2569-WGERO  Female              0      No         No      72
#
#      PhoneService MultipleLines InternetService       OnlineSecurity  \
# 11            Yes            No              No  No internet service
# 16            Yes            No              No  No internet service
# 21            Yes            No              No  No internet service
# 22            Yes            No              No  No internet service
# 33            Yes            No              No  No internet service
# 42            Yes            No              No  No internet service
# 58            Yes           Yes              No  No internet service
# 68            Yes            No              No  No internet service
# 71            Yes            No              No  No internet service
# 73            Yes           Yes              No  No internet service
# 79            Yes           Yes              No  No internet service
# 84            Yes            No              No  No internet service
# 87            Yes            No              No  No internet service
# 88            Yes            No              No  No internet service
# 97            Yes            No              No  No internet service
# 98            Yes            No              No  No internet service
# 100           Yes            No              No  No internet service
# 101           Yes            No              No  No internet service
# 109           Yes            No              No  No internet service
# 118           Yes            No              No  No internet service
# 121           Yes            No              No  No internet service
# 124           Yes            No              No  No internet service
# 127           Yes           Yes              No  No internet service
# 128           Yes            No              No  No internet service
# 135           Yes           Yes              No  No internet service
# 137           Yes            No              No  No internet service
# 138           Yes            No              No  No internet service
# 144           Yes           Yes              No  No internet service
# 146           Yes            No              No  No internet service
# 154           Yes            No              No  No internet service
# ...           ...           ...             ...                  ...
# 6830          Yes            No              No  No internet service
# 6832          Yes            No              No  No internet service
# 6840          Yes            No              No  No internet service
# 6842          Yes            No              No  No internet service
# 6854          Yes            No              No  No internet service
# 6856          Yes           Yes              No  No internet service
# 6867          Yes            No              No  No internet service
# 6875          Yes            No              No  No internet service
# 6880          Yes           Yes              No  No internet service
# 6887          Yes           Yes              No  No internet service
# 6906          Yes            No              No  No internet service
# 6911          Yes            No              No  No internet service
# 6916          Yes            No              No  No internet service
# 6920          Yes            No              No  No internet service
# 6925          Yes            No              No  No internet service
# 6929          Yes            No              No  No internet service
# 6942          Yes            No              No  No internet service
# 6944          Yes            No              No  No internet service
# 6951          Yes            No              No  No internet service
# 6954          Yes            No              No  No internet service
# 6958          Yes            No              No  No internet service
# 6969          Yes            No              No  No internet service
# 6994          Yes           Yes              No  No internet service
# 7000          Yes            No              No  No internet service
# 7005          Yes            No              No  No internet service
# 7017          Yes            No              No  No internet service
# 7019          Yes            No              No  No internet service
# 7020          Yes            No              No  No internet service
# 7030          Yes            No              No  No internet service
# 7037          Yes            No              No  No internet service
#
#              OnlineBackup     DeviceProtection          TechSupport  \
# 11    No internet service  No internet service  No internet service
# 16    No internet service  No internet service  No internet service
# 21    No internet service  No internet service  No internet service
# 22    No internet service  No internet service  No internet service
# 33    No internet service  No internet service  No internet service
# 42    No internet service  No internet service  No internet service
# 58    No internet service  No internet service  No internet service
# 68    No internet service  No internet service  No internet service
# 71    No internet service  No internet service  No internet service
# 73    No internet service  No internet service  No internet service
# 79    No internet service  No internet service  No internet service
# 84    No internet service  No internet service  No internet service
# 87    No internet service  No internet service  No internet service
# 88    No internet service  No internet service  No internet service
# 97    No internet service  No internet service  No internet service
# 98    No internet service  No internet service  No internet service
# 100   No internet service  No internet service  No internet service
# 101   No internet service  No internet service  No internet service
# 109   No internet service  No internet service  No internet service
# 118   No internet service  No internet service  No internet service
# 121   No internet service  No internet service  No internet service
# 124   No internet service  No internet service  No internet service
# 127   No internet service  No internet service  No internet service
# 128   No internet service  No internet service  No internet service
# 135   No internet service  No internet service  No internet service
# 137   No internet service  No internet service  No internet service
# 138   No internet service  No internet service  No internet service
# 144   No internet service  No internet service  No internet service
# 146   No internet service  No internet service  No internet service
# 154   No internet service  No internet service  No internet service
# ...                   ...                  ...                  ...
# 6830  No internet service  No internet service  No internet service
# 6832  No internet service  No internet service  No internet service
# 6840  No internet service  No internet service  No internet service
# 6842  No internet service  No internet service  No internet service
# 6854  No internet service  No internet service  No internet service
# 6856  No internet service  No internet service  No internet service
# 6867  No internet service  No internet service  No internet service
# 6875  No internet service  No internet service  No internet service
# 6880  No internet service  No internet service  No internet service
# 6887  No internet service  No internet service  No internet service
# 6906  No internet service  No internet service  No internet service
# 6911  No internet service  No internet service  No internet service
# 6916  No internet service  No internet service  No internet service
# 6920  No internet service  No internet service  No internet service
# 6925  No internet service  No internet service  No internet service
# 6929  No internet service  No internet service  No internet service
# 6942  No internet service  No internet service  No internet service
# 6944  No internet service  No internet service  No internet service
# 6951  No internet service  No internet service  No internet service
# 6954  No internet service  No internet service  No internet service
# 6958  No internet service  No internet service  No internet service
# 6969  No internet service  No internet service  No internet service
# 6994  No internet service  No internet service  No internet service
# 7000  No internet service  No internet service  No internet service
# 7005  No internet service  No internet service  No internet service
# 7017  No internet service  No internet service  No internet service
# 7019  No internet service  No internet service  No internet service
# 7020  No internet service  No internet service  No internet service
# 7030  No internet service  No internet service  No internet service
# 7037  No internet service  No internet service  No internet service
#
#               StreamingTV      StreamingMovies        Contract  \
# 11    No internet service  No internet service        Two year
# 16    No internet service  No internet service        One year
# 21    No internet service  No internet service        One year
# 22    No internet service  No internet service  Month-to-month
# 33    No internet service  No internet service  Month-to-month
# 42    No internet service  No internet service        One year
# 58    No internet service  No internet service        Two year
# 68    No internet service  No internet service        Two year
# 71    No internet service  No internet service        One year
# 73    No internet service  No internet service        Two year
# 79    No internet service  No internet service        One year
# 84    No internet service  No internet service        Two year
# 87    No internet service  No internet service        Two year
# 88    No internet service  No internet service        Two year
# 97    No internet service  No internet service  Month-to-month
# 98    No internet service  No internet service        Two year
# 100   No internet service  No internet service  Month-to-month
# 101   No internet service  No internet service  Month-to-month
# 109   No internet service  No internet service        Two year
# 118   No internet service  No internet service        Two year
# 121   No internet service  No internet service  Month-to-month
# 124   No internet service  No internet service  Month-to-month
# 127   No internet service  No internet service        Two year
# 128   No internet service  No internet service  Month-to-month
# 135   No internet service  No internet service        Two year
# 137   No internet service  No internet service        Two year
# 138   No internet service  No internet service        Two year
# 144   No internet service  No internet service        Two year
# 146   No internet service  No internet service        One year
# 154   No internet service  No internet service  Month-to-month
# ...                   ...                  ...             ...
# 6830  No internet service  No internet service        Two year
# 6832  No internet service  No internet service        Two year
# 6840  No internet service  No internet service  Month-to-month
# 6842  No internet service  No internet service        One year
# 6854  No internet service  No internet service  Month-to-month
# 6856  No internet service  No internet service        Two year
# 6867  No internet service  No internet service        Two year
# 6875  No internet service  No internet service        Two year
# 6880  No internet service  No internet service        Two year
# 6887  No internet service  No internet service        Two year
# 6906  No internet service  No internet service        Two year
# 6911  No internet service  No internet service        Two year
# 6916  No internet service  No internet service        Two year
# 6920  No internet service  No internet service        Two year
# 6925  No internet service  No internet service        One year
# 6929  No internet service  No internet service  Month-to-month
# 6942  No internet service  No internet service        Two year
# 6944  No internet service  No internet service  Month-to-month
# 6951  No internet service  No internet service        Two year
# 6954  No internet service  No internet service  Month-to-month
# 6958  No internet service  No internet service        Two year
# 6969  No internet service  No internet service  Month-to-month
# 6994  No internet service  No internet service        One year
# 7000  No internet service  No internet service        One year
# 7005  No internet service  No internet service        One year
# 7017  No internet service  No internet service        Two year
# 7019  No internet service  No internet service        Two year
# 7020  No internet service  No internet service  Month-to-month
# 7030  No internet service  No internet service  Month-to-month
# 7037  No internet service  No internet service        Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 11                 No    Credit card (automatic)           18.95
# 16                 No               Mailed check           20.65
# 21                 No  Bank transfer (automatic)           19.80
# 22                 No               Mailed check           20.15
# 33                 No  Bank transfer (automatic)           20.20
# 42                 No               Mailed check           20.75
# 58                 No    Credit card (automatic)           24.95
# 68                 No  Bank transfer (automatic)           20.15
# 71                Yes           Electronic check           20.40
# 73                Yes  Bank transfer (automatic)           24.25
# 79                Yes    Credit card (automatic)           25.90
# 84                Yes  Bank transfer (automatic)           20.15
# 87                 No  Bank transfer (automatic)           20.65
# 88                Yes               Mailed check           19.95
# 97                 No               Mailed check           21.05
# 98                 No  Bank transfer (automatic)           21.00
# 100                No               Mailed check           20.20
# 101                No           Electronic check           19.45
# 109                No    Credit card (automatic)           19.40
# 118                No               Mailed check           20.65
# 121                No               Mailed check           20.70
# 124                No               Mailed check           20.85
# 127               Yes  Bank transfer (automatic)           23.55
# 128                No               Mailed check           19.75
# 135               Yes    Credit card (automatic)           25.70
# 137                No               Mailed check           20.20
# 138               Yes               Mailed check           19.60
# 144                No  Bank transfer (automatic)           23.95
# 146                No               Mailed check           19.60
# 154                No               Mailed check           19.70
# ...               ...                        ...             ...
# 6830              Yes               Mailed check           20.20
# 6832               No               Mailed check           20.90
# 6840              Yes               Mailed check           19.30
# 6842              Yes               Mailed check           19.95
# 6854               No               Mailed check           20.00
# 6856               No    Credit card (automatic)           25.15
# 6867               No  Bank transfer (automatic)           19.95
# 6875               No    Credit card (automatic)           19.45
# 6880               No  Bank transfer (automatic)           25.20
# 6887               No  Bank transfer (automatic)           24.30
# 6906              Yes               Mailed check           18.70
# 6911              Yes  Bank transfer (automatic)           20.10
# 6916               No  Bank transfer (automatic)           19.55
# 6920               No    Credit card (automatic)           19.70
# 6925               No               Mailed check           18.80
# 6929               No    Credit card (automatic)           20.05
# 6942              Yes    Credit card (automatic)           20.00
# 6944              Yes               Mailed check           19.10
# 6951              Yes    Credit card (automatic)           19.90
# 6954              Yes               Mailed check           19.80
# 6958              Yes  Bank transfer (automatic)           19.75
# 6969               No               Mailed check           20.50
# 6994              Yes  Bank transfer (automatic)           24.45
# 7000               No           Electronic check           20.55
# 7005               No    Credit card (automatic)           19.30
# 7017               No  Bank transfer (automatic)           20.65
# 7019               No               Mailed check           20.15
# 7020              Yes           Electronic check           19.20
# 7030              Yes               Mailed check           20.05
# 7037              Yes  Bank transfer (automatic)           21.15
#
#       TotalCharges Churn
# 11          326.80    No
# 16         1022.95    No
# 21          202.25    No
# 22           20.15   Yes
# 33           20.20    No
# 42          418.25    No
# 58          894.30    No
# 68          930.90    No
# 71         1090.65    No
# 73         1424.60    No
# 79         1216.60    No
# 84          973.35    No
# 87         1057.00    No
# 88          927.10    No
# 97          113.85   Yes
# 98         1107.20    No
# 100          20.20    No
# 101          19.45    No
# 109        1363.25    No
# 118         835.15    No
# 121         112.75    No
# 124          62.90    No
# 127        1723.95    No
# 128          19.75    No
# 135        1188.20    No
# 137        1277.75    No
# 138        1170.55    No
# 144        1756.20    No
# 146          61.35    No
# 154         113.50    No
# ...            ...   ...
# 6830        684.40    No
# 6832       1146.05    No
# 6840         19.30    No
# 6842        257.00    No
# 6854         32.70    No
# 6856       1509.90    No
# 6867       1311.75    No
# 6875       1208.60    No
# 6880       1787.35    No
# 6887        821.60    No
# 6906        383.65    No
# 6911       1087.70    No
# 6916        819.95    No
# 6920        509.30    No
# 6925        294.95    No
# 6929        471.70    No
# 6942       1396.00    No
# 6944         53.05    No
# 6951       1022.60    No
# 6954        309.40    No
# 6958        246.70    No
# 6969         20.50   Yes
# 6994        993.15    No
# 7000       1343.40    No
# 7005        486.20    No
# 7017       1020.75    No
# 7019        826.00    No
# 7020        239.00    No
# 7030         39.25    No
# 7037       1419.40    No
#
# [1526 rows x 21 columns]

# %%
#replace 'No internet service' to No for the following columns
replace_cols = [ 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection',
                'TechSupport','StreamingTV', 'StreamingMovies']
for i in replace_cols : 
    tc[i]  = tc[i].replace({'No internet service' : 'No'})

# %%
tc['SeniorCitizen']=tc['SeniorCitizen'].replace([0,1],['No','Yes'])
# 'SeniorCitizen' has only 1's and 0's and it is a categorical column so converting it into object

# %%
tc['SeniorCitizen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null object
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7032 non-null float64
# Churn               7043 non-null object
# dtypes: float64(2), int64(1), object(18)
# memory usage: 1.1+ MB

# %% [markdown]
# # EXPLORATORY DATA ANALYSIS

# %%
del tc['customerID']
#  customerID is the unqiue column and we cant get any insights from this, and hence it's removed

# %%
tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
# gender              7043 non-null object
# SeniorCitizen       7043 non-null object
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7032 non-null float64
# Churn               7043 non-null object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 1.1+ MB

# %%
for i in tc.columns:
    print(i,':',tc[i].nunique())
# Out:
# gender : 2
# SeniorCitizen : 2
# Partner : 2
# Dependents : 2
# tenure : 73
# PhoneService : 2
# MultipleLines : 3
# InternetService : 3
# OnlineSecurity : 2
# OnlineBackup : 2
# DeviceProtection : 2
# TechSupport : 2
# StreamingTV : 2
# StreamingMovies : 2
# Contract : 3
# PaperlessBilling : 2
# PaymentMethod : 4
# MonthlyCharges : 1585
# TotalCharges : 6530
# Churn : 2

# %% [raw]
# Except 'tenure','MonthlyCharges' and 'TotalCharges' all the other columns are categorical

# %% [raw]
# for i in tc.columns:
#     print(i,':',tc[i].unique())

# %%
tc.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7032.000000
# mean     32.371149       64.761692   2283.300441
# std      24.559481       30.090047   2266.771362
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    401.450000
# 50%      29.000000       70.350000   1397.475000
# 75%      55.000000       89.850000   3794.737500
# max      72.000000      118.750000   8684.800000

# %%
df=tc[tc['TotalCharges'].isnull()]
df
# Out:
#       gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 488   Female            No     Yes        Yes       0           No
# 753     Male            No      No        Yes       0          Yes
# 936   Female            No     Yes        Yes       0          Yes
# 1082    Male            No     Yes        Yes       0          Yes
# 1340  Female            No     Yes        Yes       0           No
# 3331    Male            No     Yes        Yes       0          Yes
# 3826    Male            No     Yes        Yes       0          Yes
# 4380  Female            No     Yes        Yes       0          Yes
# 5218    Male            No     Yes        Yes       0          Yes
# 6670  Female            No     Yes        Yes       0          Yes
# 6754    Male            No      No        Yes       0          Yes
#
#          MultipleLines InternetService OnlineSecurity OnlineBackup  \
# 488   No phone service             DSL            Yes           No
# 753                 No              No             No           No
# 936                 No             DSL            Yes          Yes
# 1082               Yes              No             No           No
# 1340  No phone service             DSL            Yes          Yes
# 3331                No              No             No           No
# 3826               Yes              No             No           No
# 4380                No              No             No           No
# 5218                No              No             No           No
# 6670               Yes             DSL             No          Yes
# 6754               Yes             DSL            Yes          Yes
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# 488               Yes         Yes         Yes              No  Two year
# 753                No          No          No              No  Two year
# 936               Yes          No         Yes             Yes  Two year
# 1082               No          No          No              No  Two year
# 1340              Yes         Yes         Yes              No  Two year
# 3331               No          No          No              No  Two year
# 3826               No          No          No              No  Two year
# 4380               No          No          No              No  Two year
# 5218               No          No          No              No  One year
# 6670              Yes         Yes         Yes              No  Two year
# 6754               No         Yes          No              No  Two year
#
#      PaperlessBilling              PaymentMethod  MonthlyCharges  \
# 488               Yes  Bank transfer (automatic)           52.55
# 753                No               Mailed check           20.25
# 936                No               Mailed check           80.85
# 1082               No               Mailed check           25.75
# 1340               No    Credit card (automatic)           56.05
# 3331               No               Mailed check           19.85
# 3826               No               Mailed check           25.35
# 4380               No               Mailed check           20.00
# 5218              Yes               Mailed check           19.70
# 6670               No               Mailed check           73.35
# 6754              Yes  Bank transfer (automatic)           61.90
#
#       TotalCharges Churn
# 488            NaN    No
# 753            NaN    No
# 936            NaN    No
# 1082           NaN    No
# 1340           NaN    No
# 3331           NaN    No
# 3826           NaN    No
# 4380           NaN    No
# 5218           NaN    No
# 6670           NaN    No
# 6754           NaN    No

# %% [raw]
# we have null values only in 'TotalCharges' and we could see nulls when Dependents ='Yes', SeniorCitizen='0' and tenure=0
# and hence we impute null values with the means accordingly for males and females

# %%
con=(tc['Dependents']=='Yes') 
imp_mean=tc[con]
imp_mean.head()
# Out:
#     gender SeniorCitizen Partner Dependents  tenure PhoneService  \
# 6     Male            No      No        Yes      22          Yes
# 9     Male            No      No        Yes      62          Yes
# 10    Male            No     Yes        Yes      13          Yes
# 15  Female            No     Yes        Yes      69          Yes
# 17    Male            No      No        Yes      71          Yes
#
#    MultipleLines InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# 6            Yes     Fiber optic             No          Yes               No
# 9             No             DSL            Yes          Yes               No
# 10            No             DSL            Yes           No               No
# 15           Yes     Fiber optic            Yes          Yes              Yes
# 17           Yes     Fiber optic            Yes           No              Yes
#
#    TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 6           No         Yes              No  Month-to-month              Yes
# 9           No          No              No        One year               No
# 10          No          No              No  Month-to-month              Yes
# 15         Yes         Yes             Yes        Two year               No
# 17          No         Yes             Yes        Two year               No
#
#                 PaymentMethod  MonthlyCharges  TotalCharges Churn
# 6     Credit card (automatic)           89.10       1949.40    No
# 9   Bank transfer (automatic)           56.15       3487.95    No
# 10               Mailed check           49.95        587.45    No
# 15    Credit card (automatic)          113.25       7895.15    No
# 17  Bank transfer (automatic)          106.70       7382.25    No

# %%
male,female=imp_mean['TotalCharges'].groupby(tc['gender']).mean()
(male,female)
# Out:
# (2477.7936461388094, 2536.632016728623)

# %%
con1=(tc['gender']=='Male')& (tc['tenure']==0)
con2=(tc['TotalCharges'].isnull())
con3=con1&con2
tc[con3]=tc[con3].fillna(male)

# %%
con1=(tc['gender']=='Female')& (tc['tenure']==0)
con2=(tc['TotalCharges'].isnull())
con3=con1&con2
tc[con3]=tc[con3].fillna(female)

# %%
tc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 20 columns):
# gender              7043 non-null object
# SeniorCitizen       7043 non-null object
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null float64
# Churn               7043 non-null object
# dtypes: float64(2), int64(1), object(17)
# memory usage: 1.1+ MB

# %%
tc.describe()
# Out:
#             tenure  MonthlyCharges  TotalCharges
# count  7043.000000     7043.000000   7043.000000
# mean     32.371149       64.761692   2283.645978
# std      24.559481       30.090047   2265.017405
# min       0.000000       18.250000     18.800000
# 25%       9.000000       35.500000    402.225000
# 50%      29.000000       70.350000   1400.550000
# 75%      55.000000       89.850000   3786.600000
# max      72.000000      118.750000   8684.800000

# %%
catcols=tc.select_dtypes('object')
catcols
# Out:
#       gender SeniorCitizen Partner Dependents PhoneService     MultipleLines  \
# 0     Female            No     Yes         No           No  No phone service
# 1       Male            No      No         No          Yes                No
# 2       Male            No      No         No          Yes                No
# 3       Male            No      No         No           No  No phone service
# 4     Female            No      No         No          Yes                No
# 5     Female            No      No         No          Yes               Yes
# 6       Male            No      No        Yes          Yes               Yes
# 7     Female            No      No         No           No  No phone service
# 8     Female            No     Yes         No          Yes               Yes
# 9       Male            No      No        Yes          Yes                No
# 10      Male            No     Yes        Yes          Yes                No
# 11      Male            No      No         No          Yes                No
# 12      Male            No     Yes         No          Yes               Yes
# 13      Male            No      No         No          Yes               Yes
# 14      Male            No      No         No          Yes                No
# 15    Female            No     Yes        Yes          Yes               Yes
# 16    Female            No      No         No          Yes                No
# 17      Male            No      No        Yes          Yes               Yes
# 18    Female            No     Yes        Yes          Yes                No
# 19    Female            No      No         No          Yes                No
# 20      Male           Yes      No         No           No  No phone service
# 21      Male            No     Yes         No          Yes                No
# 22      Male            No      No         No          Yes                No
# 23    Female            No     Yes         No          Yes               Yes
# 24      Male            No     Yes        Yes          Yes                No
# 25    Female            No      No         No          Yes                No
# 26      Male            No     Yes        Yes          Yes               Yes
# 27      Male            No     Yes        Yes           No  No phone service
# 28      Male            No     Yes         No          Yes               Yes
# 29    Female            No      No        Yes          Yes                No
# ...      ...           ...     ...        ...          ...               ...
# 7013  Female            No      No         No          Yes               Yes
# 7014    Male            No      No         No          Yes               Yes
# 7015    Male           Yes     Yes         No          Yes                No
# 7016  Female            No      No         No          Yes                No
# 7017  Female            No      No         No          Yes                No
# 7018    Male            No     Yes        Yes          Yes                No
# 7019  Female            No      No         No          Yes                No
# 7020    Male            No     Yes        Yes          Yes                No
# 7021    Male            No      No         No          Yes                No
# 7022    Male            No      No         No          Yes               Yes
# 7023  Female           Yes     Yes         No          Yes               Yes
# 7024    Male            No     Yes         No          Yes               Yes
# 7025  Female            No      No         No          Yes               Yes
# 7026  Female            No      No         No          Yes                No
# 7027    Male            No      No         No          Yes                No
# 7028  Female            No     Yes         No          Yes                No
# 7029  Female           Yes      No         No           No  No phone service
# 7030  Female            No      No         No          Yes                No
# 7031    Male           Yes     Yes         No          Yes               Yes
# 7032    Male           Yes      No         No          Yes               Yes
# 7033    Male            No      No         No          Yes                No
# 7034  Female            No      No         No          Yes               Yes
# 7035    Male            No      No         No          Yes                No
# 7036  Female            No      No         No           No  No phone service
# 7037  Female            No      No         No          Yes                No
# 7038    Male            No     Yes        Yes          Yes               Yes
# 7039  Female            No     Yes        Yes          Yes               Yes
# 7040  Female            No     Yes        Yes           No  No phone service
# 7041    Male           Yes     Yes         No          Yes               Yes
# 7042    Male            No      No         No          Yes                No
#
#      InternetService OnlineSecurity OnlineBackup DeviceProtection TechSupport  \
# 0                DSL             No          Yes               No          No
# 1                DSL            Yes           No              Yes          No
# 2                DSL            Yes          Yes               No          No
# 3                DSL            Yes           No              Yes         Yes
# 4        Fiber optic             No           No               No          No
# 5        Fiber optic             No           No              Yes          No
# 6        Fiber optic             No          Yes               No          No
# 7                DSL            Yes           No               No          No
# 8        Fiber optic             No           No              Yes         Yes
# 9                DSL            Yes          Yes               No          No
# 10               DSL            Yes           No               No          No
# 11                No             No           No               No          No
# 12       Fiber optic             No           No              Yes          No
# 13       Fiber optic             No          Yes              Yes          No
# 14       Fiber optic            Yes           No              Yes         Yes
# 15       Fiber optic            Yes          Yes              Yes         Yes
# 16                No             No           No               No          No
# 17       Fiber optic            Yes           No              Yes          No
# 18               DSL             No           No              Yes         Yes
# 19       Fiber optic             No          Yes              Yes          No
# 20               DSL             No           No              Yes          No
# 21                No             No           No               No          No
# 22                No             No           No               No          No
# 23               DSL             No          Yes               No         Yes
# 24               DSL            Yes          Yes               No         Yes
# 25               DSL            Yes          Yes               No          No
# 26       Fiber optic             No          Yes               No          No
# 27               DSL             No          Yes               No          No
# 28               DSL            Yes          Yes              Yes         Yes
# 29               DSL             No           No               No          No
# ...              ...            ...          ...              ...         ...
# 7013     Fiber optic             No          Yes              Yes          No
# 7014     Fiber optic             No          Yes               No          No
# 7015     Fiber optic             No           No              Yes          No
# 7016             DSL             No          Yes               No          No
# 7017              No             No           No               No          No
# 7018     Fiber optic             No           No               No          No
# 7019              No             No           No               No          No
# 7020              No             No           No               No          No
# 7021             DSL             No           No               No         Yes
# 7022     Fiber optic             No          Yes              Yes          No
# 7023     Fiber optic             No          Yes              Yes          No
# 7024     Fiber optic            Yes           No              Yes          No
# 7025     Fiber optic             No           No              Yes         Yes
# 7026             DSL             No           No               No          No
# 7027             DSL             No          Yes               No         Yes
# 7028             DSL             No          Yes               No         Yes
# 7029             DSL             No           No               No          No
# 7030              No             No           No               No          No
# 7031             DSL            Yes          Yes               No          No
# 7032     Fiber optic             No           No               No          No
# 7033     Fiber optic             No           No               No          No
# 7034     Fiber optic            Yes          Yes              Yes          No
# 7035     Fiber optic             No           No               No          No
# 7036             DSL             No          Yes              Yes         Yes
# 7037              No             No           No               No          No
# 7038             DSL            Yes           No              Yes         Yes
# 7039     Fiber optic             No          Yes              Yes          No
# 7040             DSL            Yes           No               No          No
# 7041     Fiber optic             No           No               No          No
# 7042     Fiber optic            Yes           No              Yes         Yes
#
#      StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0             No              No  Month-to-month              Yes
# 1             No              No        One year               No
# 2             No              No  Month-to-month              Yes
# 3             No              No        One year               No
# 4             No              No  Month-to-month              Yes
# 5            Yes             Yes  Month-to-month              Yes
# 6            Yes              No  Month-to-month              Yes
# 7             No              No  Month-to-month               No
# 8            Yes             Yes  Month-to-month              Yes
# 9             No              No        One year               No
# 10            No              No  Month-to-month              Yes
# 11            No              No        Two year               No
# 12           Yes             Yes        One year               No
# 13           Yes             Yes  Month-to-month              Yes
# 14           Yes             Yes  Month-to-month              Yes
# 15           Yes             Yes        Two year               No
# 16            No              No        One year               No
# 17           Yes             Yes        Two year               No
# 18            No              No  Month-to-month               No
# 19            No             Yes  Month-to-month              Yes
# 20            No             Yes  Month-to-month              Yes
# 21            No              No        One year               No
# 22            No              No  Month-to-month               No
# 23            No              No        Two year              Yes
# 24            No              No  Month-to-month               No
# 25            No              No  Month-to-month              Yes
# 26           Yes             Yes  Month-to-month              Yes
# 27            No              No  Month-to-month               No
# 28           Yes             Yes        Two year              Yes
# 29           Yes             Yes  Month-to-month              Yes
# ...          ...             ...             ...              ...
# 7013         Yes              No  Month-to-month              Yes
# 7014         Yes              No  Month-to-month              Yes
# 7015         Yes              No  Month-to-month              Yes
# 7016          No              No  Month-to-month               No
# 7017          No              No        Two year               No
# 7018          No              No  Month-to-month              Yes
# 7019          No              No        Two year               No
# 7020          No              No  Month-to-month              Yes
# 7021         Yes              No        One year              Yes
# 7022         Yes             Yes        One year              Yes
# 7023         Yes             Yes  Month-to-month              Yes
# 7024          No              No  Month-to-month              Yes
# 7025          No             Yes  Month-to-month              Yes
# 7026          No              No  Month-to-month              Yes
# 7027         Yes             Yes  Month-to-month               No
# 7028         Yes              No        Two year               No
# 7029         Yes             Yes  Month-to-month              Yes
# 7030          No              No  Month-to-month              Yes
# 7031          No              No        One year               No
# 7032          No              No  Month-to-month              Yes
# 7033          No              No  Month-to-month              Yes
# 7034         Yes              No  Month-to-month              Yes
# 7035         Yes              No  Month-to-month              Yes
# 7036         Yes             Yes        One year               No
# 7037          No              No        Two year              Yes
# 7038         Yes             Yes        One year              Yes
# 7039         Yes             Yes        One year              Yes
# 7040          No              No  Month-to-month              Yes
# 7041          No              No  Month-to-month              Yes
# 7042         Yes             Yes        Two year              Yes
#
#                   PaymentMethod Churn
# 0              Electronic check    No
# 1                  Mailed check    No
# 2                  Mailed check   Yes
# 3     Bank transfer (automatic)    No
# 4              Electronic check   Yes
# 5              Electronic check   Yes
# 6       Credit card (automatic)    No
# 7                  Mailed check    No
# 8              Electronic check   Yes
# 9     Bank transfer (automatic)    No
# 10                 Mailed check    No
# 11      Credit card (automatic)    No
# 12      Credit card (automatic)    No
# 13    Bank transfer (automatic)   Yes
# 14             Electronic check    No
# 15      Credit card (automatic)    No
# 16                 Mailed check    No
# 17    Bank transfer (automatic)    No
# 18      Credit card (automatic)   Yes
# 19             Electronic check    No
# 20             Electronic check   Yes
# 21    Bank transfer (automatic)    No
# 22                 Mailed check   Yes
# 23      Credit card (automatic)    No
# 24      Credit card (automatic)    No
# 25    Bank transfer (automatic)    No
# 26             Electronic check   Yes
# 27             Electronic check   Yes
# 28      Credit card (automatic)    No
# 29                 Mailed check   Yes
# ...                         ...   ...
# 7013  Bank transfer (automatic)    No
# 7014           Electronic check    No
# 7015    Credit card (automatic)    No
# 7016           Electronic check    No
# 7017  Bank transfer (automatic)    No
# 7018               Mailed check   Yes
# 7019               Mailed check    No
# 7020           Electronic check    No
# 7021           Electronic check   Yes
# 7022           Electronic check    No
# 7023           Electronic check    No
# 7024    Credit card (automatic)    No
# 7025  Bank transfer (automatic)    No
# 7026  Bank transfer (automatic)   Yes
# 7027               Mailed check    No
# 7028  Bank transfer (automatic)    No
# 7029           Electronic check    No
# 7030               Mailed check    No
# 7031    Credit card (automatic)    No
# 7032           Electronic check   Yes
# 7033    Credit card (automatic)    No
# 7034    Credit card (automatic)   Yes
# 7035  Bank transfer (automatic)    No
# 7036           Electronic check    No
# 7037  Bank transfer (automatic)    No
# 7038               Mailed check    No
# 7039    Credit card (automatic)    No
# 7040           Electronic check    No
# 7041               Mailed check   Yes
# 7042  Bank transfer (automatic)    No
#
# [7043 rows x 17 columns]

# %%
# Taking all columns whose categories are more than 2 and check if they are significantly different
l=[]
for i in catcols.columns:
    if catcols[i].nunique()>2:
        l.append(i)
print(l)
# Out:
# ['MultipleLines', 'InternetService', 'Contract', 'PaymentMethod']

# %%
# Since there are more two categories we perform chi2_contingency
# we consider those columns whose p_val is <0.05
from scipy.stats import chi2_contingency
f=[]
for i in l:
    cc=chi2_contingency(pd.crosstab(catcols['Churn'],catcols[i]))
    if(cc[1]<=0.05):
        f.append(i)
print(f)
# Out:
# ['MultipleLines', 'InternetService', 'Contract', 'PaymentMethod']

# %% [raw]
# From the above fun we decide to keep the values whose p value is <0.05

# %%
# Taking all columns whose categories are less than 2 and check if they are significantly different
k=[]
for i in catcols.columns:
    if catcols[i].nunique()==2:
        k.append(i)
k.pop(-1) # since 'Churn' is our predictive varibale we remove it from here, to compare every categorical value with 'Churn'
print(k)
# Out:
# ['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling']

# %% [markdown]
# # PROPORTION Z_TEST

# %%
# Since there are two categories we perform proportions_ztest
# we consider those columns whose p_val is <0.05
from statsmodels.stats.proportion import proportions_ztest
g=[]
for i in k:
    c=pd.crosstab(tc['Churn'],tc[i])
    x1=c.iloc[1,1]
    x2=c.iloc[1,0]
    n1=c.iloc[:,1].sum()
    n2=c.iloc[:,0].sum()
    cc=proportions_ztest([x1,x2],[n1,n2])
    if(cc[1]<=0.05):
        g.append(i)
print(g)
# Out:
# ['SeniorCitizen', 'Partner', 'Dependents', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling']

# %% [raw]
# Gender and PhoneService are not statistically significant so we remove them for further analysis

# %%
# List of categorical whose p<0.05 after proportion_ztest and chi2_contingency test
f_list=f+g
print(f_list,'\n')
print('Total number of required columns:',len(f_list))
# Out:
# ['MultipleLines', 'InternetService', 'Contract', 'PaymentMethod', 'SeniorCitizen', 'Partner', 'Dependents', 'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies', 'PaperlessBilling']
#
# Total number of required columns: 14

# %%
tc['Churn'].value_counts(),
# Out:
# (No     5174
#  Yes    1869
#  Name: Churn, dtype: int64,)

# %%
f_list
# Out:
# ['MultipleLines',
#  'InternetService',
#  'Contract',
#  'PaymentMethod',
#  'SeniorCitizen',
#  'Partner',
#  'Dependents',
#  'OnlineSecurity',
#  'OnlineBackup',
#  'DeviceProtection',
#  'TechSupport',
#  'StreamingTV',
#  'StreamingMovies',
#  'PaperlessBilling']

# %%
plt.pie(tc['Churn'].value_counts(),explode=(0,0.09),autopct='%1.1f%%',labels=('No','Yes'),shadow=True)
plt.savefig('Churn pct')
plt.show()

# %%
fig,axes=plt.subplots(4,4,figsize=(20,20))
axes=axes.flatten()
for i in range(0,len(f_list)):
    sns.countplot(tc[f_list[i]],hue=tc['Churn'],ax=axes[i])
plt.tight_layout()
plt.savefig('Attribute wise comparison with Churn')
plt.show()

# %%
# creating one hot encoding for the selected columns
tc_dum=pd.get_dummies(tc[f_list])
tc_dum.head()
print(tc_dum.shape)
# Out:
# (7043, 33)

# %%
num=tc.select_dtypes(['int64','float'])
num
X=pd.concat([tc_dum,num],axis=1)
y=tc['Churn']

# %% [markdown]
# # SPLITTING THE DATA INTO TRAIN AND TEST

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,random_state = 7,test_size=0.30)

# %% [markdown]
# # LOGISTIC REGRESSION (CLASSIFICATION)

# %%
from sklearn.linear_model import LogisticRegression
logreg=LogisticRegression()
logreg_result=logreg.fit(X_train,y_train)

print("Training set score: {:.3f}".format(logreg_result.score(X_train,y_train)))
print("Test score: {:.3f}".format(logreg_result.score(X_test,y_test)))
# Out:
# Training set score: 0.806
# Test score: 0.804

# %%
logreg_result
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
y_pred  = logreg.predict(X_test)
y_proba = logreg.predict_proba(X_test)
y_proba
# y_proba consists of p and (1-p) values, but we use (1-p) values for roc curve
# Out:
# array([[0.89231907, 0.10768093],
#        [0.46601003, 0.53398997],
#        [0.3591499 , 0.6408501 ],
#        ...,
#        [0.98951353, 0.01048647],
#        [0.48166719, 0.51833281],
#        [0.99299792, 0.00700208]])

# %%
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import auc
from sklearn.metrics import accuracy_score,classification_report

y_test1=y_test.replace(['Yes','No'],[True,False])
y_train1=y_train.replace(['Yes','No'],[True,False])
fpr, tpr, thresholds = roc_curve(y_test1, y_proba[:,1])

# %%
plt.plot(fpr,tpr)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Logistic Regression')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)

roc_auc = auc(fpr,tpr)
print("Area under the curve for LOGISTIC REGRESSION: " , roc_auc)
# Out:
# Area under the curve for LOGISTIC REGRESSION:  0.84349224935876

# %%
from statsmodels.tools import add_constant as add_constant
import statsmodels.api as sm
X_train1=sm.add_constant(X_train)
logit_model=sm.Logit(y_train1,X_train1)
result=logit_model.fit()
print(result.summary2())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.409573
#          Iterations: 35
#                                              Results: Logit
# ========================================================================================================
# Model:                            Logit                         Pseudo R-squared:              0.285
# Dependent Variable:               Churn                         AIC:                           4084.3857
# Date:                             2019-09-05 11:11              BIC:                           4233.9568
# No. Observations:                 4930                          Log-Likelihood:                -2019.2
# Df Model:                         22                            LL-Null:                       -2824.3
# Df Residuals:                     4907                          LLR p-value:                   0.0000
# Converged:                        0.0000                        Scale:                         1.0000
# No. Iterations:                   35.0000
# --------------------------------------------------------------------------------------------------------
#                                           Coef.     Std.Err.      z    P>|z|      [0.025       0.975]
# --------------------------------------------------------------------------------------------------------
# const                                    139.4211 2272401.6944  0.0001 1.0000 -4453686.0583 4453964.9004
# MultipleLines_No                        -149.4052 2012719.7693 -0.0001 0.9999 -3945007.6640 3944708.8535
# MultipleLines_No phone service          -148.9197 1928496.0911 -0.0001 0.9999 -3779931.8025 3779633.9631
# MultipleLines_Yes                       -149.1103 2127842.1035 -0.0001 0.9999 -4170642.9980 4170344.7773
# InternetService_DSL                       -5.7792 2234621.6544 -0.0000 1.0000 -4379783.7408 4379772.1825
# InternetService_Fiber optic               -4.7364 2318564.3070 -0.0000 1.0000 -4544307.2740 4544297.8012
# InternetService_No                        -6.7837 2306667.9233 -0.0000 1.0000 -4520992.8376 4520979.2703
# Contract_Month-to-month                   12.8401          nan     nan    nan           nan          nan
# Contract_One year                         12.1213          nan     nan    nan           nan          nan
# Contract_Two year                         11.4243          nan     nan    nan           nan          nan
# PaymentMethod_Bank transfer (automatic)    0.6127          nan     nan    nan           nan          nan
# PaymentMethod_Credit card (automatic)      0.5281          nan     nan    nan           nan          nan
# PaymentMethod_Electronic check             0.8936          nan     nan    nan           nan          nan
# PaymentMethod_Mailed check                 0.6112          nan     nan    nan           nan          nan
# SeniorCitizen_No                          -0.4636          nan     nan    nan           nan          nan
# SeniorCitizen_Yes                         -0.2745          nan     nan    nan           nan          nan
# Partner_No                                 2.4278 1236581.8686  0.0000 1.0000 -2423653.4987 2423658.3542
# Partner_Yes                                2.3925 1244585.7183  0.0000 1.0000 -2439340.7911 2439345.5761
# Dependents_No                              5.0287  210551.7916  0.0000 1.0000  -412668.8997  412678.9571
# Dependents_Yes                             4.8688  202419.2871  0.0000 1.0000  -396729.6437  396739.3812
# OnlineSecurity_No                         -0.5220          nan     nan    nan           nan          nan
# OnlineSecurity_Yes                        -1.0023          nan     nan    nan           nan          nan
# OnlineBackup_No                            2.2171  477888.3374  0.0000 1.0000  -936641.7129  936646.1471
# OnlineBackup_Yes                           2.1864  180624.8136  0.0000 1.0000  -354015.9430  354020.3158
# DeviceProtection_No                        4.3215 1270885.5342  0.0000 1.0000 -2490885.5541 2490894.1970
# DeviceProtection_Yes                       4.2619 1351672.3362  0.0000 1.0000 -2649224.8359 2649233.3598
# TechSupport_No                            18.5512          nan     nan    nan           nan          nan
# TechSupport_Yes                           18.1420          nan     nan    nan           nan          nan
# StreamingTV_No                           -28.7867 1152710.0414 -0.0000 1.0000 -2259298.9525 2259241.3790
# StreamingTV_Yes                          -28.5090 1188186.3141 -0.0000 1.0000 -2328830.8916 2328773.8736
# StreamingMovies_No                        -0.3388          nan     nan    nan           nan          nan
# StreamingMovies_Yes                       -0.0445          nan     nan    nan           nan          nan
# PaperlessBilling_No                       -0.1541          nan     nan    nan           nan          nan
# PaperlessBilling_Yes                       0.0841          nan     nan    nan           nan          nan
# tenure                                    -0.0581       0.0073 -7.9094 0.0000       -0.0724      -0.0437
# MonthlyCharges                            -0.0096       0.0385 -0.2494 0.8030       -0.0851       0.0659
# TotalCharges                               0.0003       0.0001  3.7111 0.0002        0.0001       0.0005
# ========================================================================================================
# C:\Users\ADARSH PC\Anaconda3\lib\site-packages\statsmodels\base\model.py:508: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   "Check mle_retvals", ConvergenceWarning)

# %% [markdown]
# # RECURSIVE FEATURE ELIMINATION

# %% [raw]
# To find the best columns suitable for the analysis

# %%
from sklearn.feature_selection import RFE

logit = LogisticRegression()

rfe = RFE(logit,10)
rfe = rfe.fit(X_train,y_train)

print(rfe.support_)
print(rfe.ranking_)
#identified columns Recursive Feature Elimination
# Out:
# [False  True False False  True  True  True  True  True  True  True False
#  False False False False False False False False  True False False False
#  False False  True False False False False False False False False False]
# [20  1 23 14  1  1  1  1  1  1  1 11 19 13 22 16  2 24  9 15  1 17  5 12
#   8 18  1  3  4  7 10  6 26 21 25 27]

# %%
idc_rfe = pd.DataFrame({"rfe_support" :rfe.support_,
                       "columns" :X_train.columns ,
                       "ranking" : rfe.ranking_,
                      })
cols = idc_rfe[idc_rfe["rfe_support"] == True]["columns"].tolist()
cols
# Out:
# ['MultipleLines_No phone service',
#  'InternetService_Fiber optic',
#  'InternetService_No',
#  'Contract_Month-to-month',
#  'Contract_One year',
#  'Contract_Two year',
#  'PaymentMethod_Bank transfer (automatic)',
#  'PaymentMethod_Credit card (automatic)',
#  'OnlineSecurity_Yes',
#  'TechSupport_Yes']

# %%
# From the RFE we filter the best columns where support is True
X_train_rfe=X_train[cols]
X_test_rfe=X_test[cols]

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import RandomForestClassifier
RF_model=RandomForestClassifier(random_state=10)
RF_results=RF_model.fit(X_train_rfe,y_train)

# %%
y_pred_test = RF_model.predict(X_test_rfe)
y_pred_train = RF_model.predict(X_train_rfe)

# %%
print(classification_report(y_train,y_pred_train))
print('Train Accuracy Score for Random Forest 1st attempt',accuracy_score(y_train,y_pred_train))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.89      0.86      3649
#          Yes       0.61      0.51      0.55      1281
#
#    micro avg       0.79      0.79      0.79      4930
#    macro avg       0.73      0.70      0.71      4930
# weighted avg       0.78      0.79      0.78      4930
#
# Train Accuracy Score for Random Forest 1st attempt 0.7890466531440162

# %%
print(classification_report(y_test,y_pred_test))
print('Test Accuracy Score for Random Forest 1st attempt',accuracy_score(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.88      0.85      1525
#          Yes       0.62      0.48      0.54       588
#
#    micro avg       0.77      0.77      0.77      2113
#    macro avg       0.72      0.68      0.69      2113
# weighted avg       0.76      0.77      0.76      2113
#
# Test Accuracy Score for Random Forest 1st attempt 0.7723615712257453

# %% [markdown]
# # GRID SEARCH

# %%
from sklearn.model_selection import GridSearchCV
RF_model=RandomForestClassifier(n_estimators=10,random_state=10)
param_grid_rf={'n_estimators':[11,12,13,9],'max_features':['auto','sqrt'],}
clf=GridSearchCV(RF_model,param_grid_rf,cv=2)
clf.fit(X_train_rfe,y_train)
# Out:
# GridSearchCV(cv=2, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=10, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [11, 12, 13, 9], 'max_features': ['auto', 'sqrt']},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
clf.best_params_
# Out:
# {'max_features': 'auto', 'n_estimators': 9}

# %%
RF_best_model=RandomForestClassifier(n_estimators=9,random_state=10)
RF_best_model.fit(X_train_rfe,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=9, n_jobs=None,
#             oob_score=False, random_state=10, verbose=0, warm_start=False)

# %%
y_train_pred=clf.predict(X_train_rfe)
y_test_pred=clf.predict(X_test_rfe)
(y_train_pred,y_test_pred)
# Out:
# (array(['No', 'Yes', 'No', ..., 'No', 'No', 'No'], dtype=object),
#  array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object))

# %%
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
print(classification_report(y_train,y_train_pred))
print('Train Accuracy Random Forest after Grid Search CV :',accuracy_score(y_train,y_train_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.84      0.89      0.86      3649
#          Yes       0.61      0.51      0.55      1281
#
#    micro avg       0.79      0.79      0.79      4930
#    macro avg       0.73      0.70      0.71      4930
# weighted avg       0.78      0.79      0.78      4930
#
# Train Accuracy Random Forest after Grid Search CV : 0.7890466531440162

# %%
print(classification_report(y_test,y_test_pred))
print('Test Accuracy Random Forest after Grid Search CV :',accuracy_score(y_test,y_test_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.88      0.85      1525
#          Yes       0.62      0.48      0.54       588
#
#    micro avg       0.77      0.77      0.77      2113
#    macro avg       0.72      0.68      0.69      2113
# weighted avg       0.76      0.77      0.76      2113
#
# Test Accuracy Random Forest after Grid Search CV : 0.7723615712257453

# %%
y_test_pred=pd.DataFrame(RF_best_model.predict(X_test_rfe))
y_proba_rf = RF_best_model.predict_proba(X_test_rfe)
# y_proba_rf

# %%
y_test1=y_test.replace(['Yes','No'],[True,False])
y_train1=y_train.replace(['Yes','No'],[True,False])
fpr1, tpr1, thresholds = roc_curve(y_test1, y_proba_rf[:,1])
(fpr1, tpr1)
# print(len(y_proba_rf[:,1]))
# Out:
# (array([0.        , 0.07803279, 0.0957377 , 0.11409836, 0.11540984,
#         0.11803279, 0.1357377 , 0.13639344, 0.13836066, 0.13901639,
#         0.15344262, 0.1947541 , 0.21639344, 0.22229508, 0.22360656,
#         0.23344262, 0.23672131, 0.2452459 , 0.2557377 , 0.26754098,
#         0.27016393, 0.28065574, 0.28918033, 0.29508197, 0.30098361,
#         0.30622951, 0.30819672, 0.3095082 , 0.31803279, 0.32      ,
#         0.32721311, 0.33704918, 0.3495082 , 0.40786885, 0.42163934,
#         0.42688525, 0.43606557, 0.44131148, 0.44262295, 0.44786885,
#         0.44852459, 0.45442623, 0.45770492, 0.46360656, 0.46622951,
#         0.47213115, 0.47540984, 0.48459016, 0.48786885, 0.49245902,
#         0.4957377 , 0.50163934, 0.50491803, 0.51016393, 0.51344262,
#         0.51868852, 0.52786885, 0.53311475, 0.53770492, 0.54557377,
#         0.54819672, 0.55606557, 0.56      , 0.56262295, 0.56590164,
#         0.57639344, 0.58557377, 0.60131148, 0.60918033, 0.61114754,
#         0.6157377 , 0.61967213, 0.63147541, 0.63606557, 0.65770492,
#         0.67409836, 0.69114754, 0.70688525, 0.7495082 , 0.79081967,
#         0.84065574, 0.87606557, 1.        ]),
#  array([0.        , 0.3792517 , 0.42346939, 0.48129252, 0.48129252,
#         0.48809524, 0.53401361, 0.53401361, 0.53571429, 0.53571429,
#         0.58673469, 0.65306122, 0.70918367, 0.71428571, 0.71428571,
#         0.71938776, 0.72108844, 0.7244898 , 0.73469388, 0.73809524,
#         0.74489796, 0.75510204, 0.76020408, 0.76360544, 0.77210884,
#         0.7755102 , 0.77721088, 0.77891156, 0.78061224, 0.78741497,
#         0.79931973, 0.80442177, 0.81802721, 0.84693878, 0.86054422,
#         0.86734694, 0.86904762, 0.86904762, 0.86904762, 0.8707483 ,
#         0.87414966, 0.88435374, 0.88605442, 0.89115646, 0.89455782,
#         0.90306122, 0.90816327, 0.91156463, 0.91326531, 0.91496599,
#         0.91836735, 0.91836735, 0.92006803, 0.92346939, 0.92517007,
#         0.92857143, 0.93197279, 0.93537415, 0.93537415, 0.93877551,
#         0.93877551, 0.94047619, 0.94387755, 0.94387755, 0.94387755,
#         0.94557823, 0.95068027, 0.95238095, 0.95238095, 0.95578231,
#         0.95918367, 0.96088435, 0.96768707, 0.97108844, 0.97108844,
#         0.9744898 , 0.97619048, 0.97959184, 0.98129252, 0.98469388,
#         0.98639456, 0.98639456, 1.        ]))

# %%
plt.plot(fpr1,tpr1)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Random Forest')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)

roc_auc1 = auc(fpr1,tpr1)
print("Area under the curve for RANDOM FOREST: " , roc_auc1)
# Out:
# Area under the curve for RANDOM FOREST:  0.8092829262852682

# %% [markdown]
# # BAGGING

# %%
from sklearn.ensemble import RandomForestClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import confusion_matrix

# %%
bag_model = BaggingClassifier(DecisionTreeClassifier(random_state=1))
bag_model.fit(X_train_rfe,y_train)
# Out:
# BaggingClassifier(base_estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=1,
#             splitter='best'),
#          bootstrap=True, bootstrap_features=False, max_features=1.0,
#          max_samples=1.0, n_estimators=10, n_jobs=None, oob_score=False,
#          random_state=None, verbose=0, warm_start=False)

# %%
bag_pred = bag_model.predict(X_test_rfe)
accuracy_score(y_test, bag_pred)
# Out:
# 0.7723615712257453

# %%
bag_cm = confusion_matrix(y_test, bag_pred)
sns.heatmap(bag_cm,annot=True,fmt='d',cmap='Blues_r')
plt.show()

# %%
print(classification_report(y_test,bag_pred))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.82      0.88      0.85      1525
#          Yes       0.62      0.48      0.54       588
#
#    micro avg       0.77      0.77      0.77      2113
#    macro avg       0.72      0.68      0.69      2113
# weighted avg       0.76      0.77      0.76      2113

# %%
y_pred_bag=bag_model.predict(X_test_rfe)
y_pred_proba_bag=bag_model.predict_proba(X_test_rfe)
fpr2, tpr2, thresholds = roc_curve(y_test1, y_pred_proba_bag[:,1])
(fpr2, tpr2)
# Out:
# (array([0.00000000e+00, 6.55737705e-04, 7.86885246e-02, 9.63934426e-02,
#         9.70491803e-02, 1.15409836e-01, 1.16721311e-01, 1.34426230e-01,
#         1.36393443e-01, 1.50819672e-01, 1.53442623e-01, 1.63278689e-01,
#         2.04590164e-01, 2.26229508e-01, 2.32131148e-01, 2.37377049e-01,
#         2.45901639e-01, 2.47213115e-01, 2.50491803e-01, 2.56393443e-01,
#         2.59016393e-01, 2.60983607e-01, 2.61639344e-01, 2.66885246e-01,
#         2.72131148e-01, 2.74754098e-01, 2.80655738e-01, 2.86557377e-01,
#         2.96393443e-01, 3.06885246e-01, 3.08196721e-01, 3.21967213e-01,
#         3.23934426e-01, 3.36393443e-01, 3.94754098e-01, 4.03278689e-01,
#         4.10491803e-01, 4.16393443e-01, 4.25573770e-01, 4.31475410e-01,
#         4.36721311e-01, 4.45245902e-01, 4.48524590e-01, 4.53770492e-01,
#         4.58360656e-01, 4.61639344e-01, 4.67540984e-01, 4.68852459e-01,
#         4.74754098e-01, 4.79344262e-01, 4.83278689e-01, 4.88524590e-01,
#         4.94426230e-01, 4.97704918e-01, 5.00983607e-01, 5.06229508e-01,
#         5.10819672e-01, 5.16065574e-01, 5.19344262e-01, 5.23934426e-01,
#         5.27213115e-01, 5.45573770e-01, 5.53442623e-01, 5.58688525e-01,
#         5.66557377e-01, 5.77049180e-01, 5.92786885e-01, 5.95409836e-01,
#         6.04590164e-01, 6.12459016e-01, 6.28852459e-01, 6.32786885e-01,
#         6.48524590e-01, 6.51803279e-01, 6.68852459e-01, 6.70819672e-01,
#         6.82622951e-01, 7.04262295e-01, 7.06885246e-01, 7.48196721e-01,
#         7.90819672e-01, 8.26229508e-01, 8.76065574e-01, 1.00000000e+00]),
#  array([0.        , 0.        , 0.3792517 , 0.42346939, 0.42346939,
#         0.48129252, 0.48129252, 0.52721088, 0.52891156, 0.57993197,
#         0.58673469, 0.59183673, 0.65816327, 0.71428571, 0.71938776,
#         0.7244898 , 0.72789116, 0.72789116, 0.72959184, 0.73129252,
#         0.73809524, 0.74489796, 0.74829932, 0.75340136, 0.75680272,
#         0.76020408, 0.76360544, 0.76530612, 0.77040816, 0.78061224,
#         0.78231293, 0.79591837, 0.79761905, 0.81122449, 0.84013605,
#         0.8452381 , 0.85714286, 0.86734694, 0.86904762, 0.87755102,
#         0.8792517 , 0.88095238, 0.88605442, 0.89285714, 0.89285714,
#         0.89455782, 0.89965986, 0.89965986, 0.89965986, 0.90306122,
#         0.90646259, 0.90986395, 0.91836735, 0.92176871, 0.92346939,
#         0.92687075, 0.93027211, 0.93027211, 0.93197279, 0.93367347,
#         0.93537415, 0.94217687, 0.94557823, 0.94897959, 0.94897959,
#         0.95068027, 0.95238095, 0.95238095, 0.95748299, 0.95918367,
#         0.96258503, 0.96428571, 0.96768707, 0.96768707, 0.96938776,
#         0.97278912, 0.97959184, 0.97959184, 0.97959184, 0.9829932 ,
#         0.98469388, 0.98469388, 0.98639456, 1.        ]))

# %%
plt.plot(fpr2,tpr2)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for Bagging')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)

roc_auc2 = auc(fpr2,tpr2)
print("Area under the curve for BAGGING: " , roc_auc2)
# Out:
# Area under the curve for BAGGING:  0.8094100591056096

# %% [markdown]
# # K-NEAREST NEIGHBORS

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn=KNeighborsClassifier()
knn.fit(X_train_rfe,y_train)
y_pred_knn=knn.predict(X_test_rfe)

# %%
accuracy_score(y_pred_knn,y_test)
# Out:
# 0.7326076668244202

# %%
y_pred_proba_knn=knn.predict_proba(X_test_rfe)
fpr3, tpr3, thresholds = roc_curve(y_test1, y_pred_proba_knn[:,1])

# %%
plt.plot(fpr3,tpr3)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for K-Nearest Neighbors')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)

roc_auc3 = auc(fpr3,tpr3)
print("Area under the curve for K-NEAREST NEIGHBORS: " , roc_auc3)
# Out:
# Area under the curve for K-NEAREST NEIGHBORS:  0.7662947474071595

# %% [markdown]
# # GRADIENT BOOSTING

# %%
from sklearn.ensemble import GradientBoostingClassifier
gb_model = GradientBoostingClassifier(learning_rate=0.01,random_state=1)
gb_model.fit(X_train_rfe,y_train)
# Out:
# GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.01, loss='deviance', max_depth=3,
#               max_features=None, max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=1, min_samples_split=2,
#               min_weight_fraction_leaf=0.0, n_estimators=100,
#               n_iter_no_change=None, presort='auto', random_state=1,
#               subsample=1.0, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
gb_pred = gb_model.predict(X_test_rfe)
accuracy_score(y_test, gb_pred)
# Out:
# 0.7217226691907241

# %%
y_pred_gb=gb_model.predict(X_test_rfe)
y_pred_proba_gb=gb_model.predict_proba(X_test_rfe)
fpr4, tpr4, thresholds = roc_curve(y_test1, y_pred_proba_gb[:,1])

# %%
plt.plot(fpr4,tpr4)
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.title('ROC curve for K-Nearest Neighbors')
plt.xlabel('False positive rate (1-Specificity)')
plt.ylabel('True positive rate (Sensitivity)')
plt.grid(True)

roc_auc4 = auc(fpr4,tpr4)
print("Area under the curve for GRADIENT BOOSTING: " , roc_auc4)
# Out:
# Area under the curve for GRADIENT BOOSTING:  0.8125805732128917

# %% [markdown]
# # COMPARING THE MODELS

# %%
# ROC Curves for Logistic Regression and Random Forest
plt.figure(figsize=(10,10))

plt.plot(fpr,tpr)# log reg
roc_auc = auc(fpr,tpr)

plt.plot(fpr1,tpr1)# rand for
roc_auc1 = auc(fpr1,tpr1)

plt.plot(fpr2,tpr2)# KNN
roc_auc2 = auc(fpr2,tpr2)

plt.plot(fpr3,tpr3)# Bagging
roc_auc3 = auc(fpr3,tpr3)

plt.plot(fpr4,tpr4)# Gradiant Boosting
roc_auc4 = auc(fpr4,tpr4)

print("Area under the curve for LOGISTIC REGRESSION: " , roc_auc)
print("Area under the curve for RANDOM FOREST:       " , roc_auc1)
print("Area under the curve for BAGGING:             " , roc_auc2)
print("Area under the curve for K-NEAREST NEIGHBORS: " , roc_auc3)
print("Area under the curve for GRADIENT BOOSTING:   " , roc_auc4)


plt.grid()
plt.title('Algorithm Wise ROC Comparison')
plt.legend(['LOGISTIC REGRESSION','RANDOM FOREST','KNN','BAGGING','GRADIENT BOSSTING'])
plt.savefig('ROC Curves')
# Out:
# Area under the curve for LOGISTIC REGRESSION:  0.84349224935876
# Area under the curve for RANDOM FOREST:        0.8092829262852682
# Area under the curve for BAGGING:              0.8094100591056096
# Area under the curve for K-NEAREST NEIGHBORS:  0.7662947474071595
# Area under the curve for GRADIENT BOOSTING:    0.8125805732128917

# %%
models = [('LOGISTIC REGRESSION', LogisticRegression()),  
          ('RANDOM FOREST', RandomForestClassifier()), 
          ('KNN', KNeighborsClassifier()), 
          ('BAGGING',BaggingClassifier()),
          ('GRADIENT BOOSTING', GradientBoostingClassifier())]

# %%
seed = 7
results = []
names = []
from sklearn.model_selection import KFold, cross_val_score
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed)
    cv_results = cross_val_score(model, X_test_rfe, y_test, cv=kfold, scoring='accuracy')
    results.append(cv_results)
    names.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LOGISTIC REGRESSION: 0.773310 (0.024993)
# RANDOM FOREST: 0.766682 (0.027381)
# KNN: 0.721260 (0.036829)
# BAGGING: 0.766210 (0.027059)
# GRADIENT BOOSTING: 0.773793 (0.031080)

# %%
fig, ax = plt.subplots(figsize=(12,6))
plt.boxplot(results)
plt.title('Algorithm Wise Test Accuracy Comparison')
ax.set_xticklabels(names,rotation=45)
plt.ylabel('')
plt.savefig('Algorithm Wise Test Accuracy Comparison')
plt.show()

# %%
seed_train = 7
results_train = []
names_train = []
from sklearn.model_selection import KFold, cross_val_score
for name, model in models:
    kfold = KFold(n_splits=10, random_state=seed_train)
    cv_results = cross_val_score(model, X_train_rfe, y_train, cv=kfold, scoring='accuracy')
    results_train.append(cv_results)
    names_train.append(name)
    msg = "%s: %f (%f)" % (name, cv_results.mean(), cv_results.std())
    print(msg)
# Out:
# LOGISTIC REGRESSION: 0.781339 (0.011751)
# RANDOM FOREST: 0.784584 (0.012164)
# KNN: 0.772414 (0.012365)
# BAGGING: 0.784381 (0.007372)
# GRADIENT BOOSTING: 0.788641 (0.009286)

# %%
plt.figure(figsize=(12,6))
fig, ax = plt.subplots(figsize=(12,6))
plt.boxplot(results_train)
plt.title('Algorithm Wise Train Accuracy Comparison')
ax.set_xticklabels(names_train,rotation=45)
plt.ylabel('')
plt.savefig('Algorithm Wise Train Accuracy Comparison')
plt.show()

# %% [markdown]
# # CONCLUSION

# %% [raw]
# From the above we can conclude that the we are able to get the best result using the classification technique of "LOGISTIC REGRESSION".
#
# We can see that both the ROC-Curves and the Accuracy scores for Logistic Regression is high and fits perfectly well for the above given data.
